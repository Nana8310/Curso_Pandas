# %% [markdown]
# Práctica 43: Limpieza, manejo y transformación de datos con Pandas

# %% [markdown]
# Cargar el fichero retail2.csv en un dataframe de Pandas y efectuar todas las operaciones de consulta, exploración y limpieza de datos que sean necesarios algunos pasos de limpieza están de forma explícita como preguntas. Los ficheros contienen varias columnas y algunas de ellas tienen datos que podrían necesitar limpieza o tratamiento.

# %% [markdown]
# ## Exploración de datos retail2

# %%
import pandas as pd
import numpy as np

# %%
retail2_df = pd.read_csv('retail2.csv')
exchange_rates_df = pd.read_csv('exchange_rates.csv')

# %%
retail2_df.head(3)
# Out:
#    InvoiceNo StockCode                                        Description  \
# 0   536578.0     84969  ["description": "BOX OF 6 ASSORTED COLOUR TEAS...
# 1   536446.0     21756                                DOORMAT NEW ENGLAND
# 2   536633.0     22632                          HAND WARMER RED POLKA DOT
#
#   Quantity      InvoiceDate UnitPrice  CustomerID         Country  \
# 0        6  12/1/2010 12:28      4.25       17763  United Kingdom
# 1      100  12/1/2010 10:16     795.0       15939  United Kingdom
# 2        6  12/1/2010 13:23      1.85       12295  United Kingdom
#
#      CustomerName                    Email  ... StockLevel Discount  \
# 0   David Johnson   david.johnson@mail.com  ...        853    17.28
# 1  Henry Williams  henry.williams@test.org  ...        910     9.08
# 2      Jane Brown      jane.brown@mail.com  ...        578    45.42
#
#   SaleChannel  ReturnStatus  ProductWeight  ProductDimensions ShippingCost  \
# 0      Online  Not Returned           3.81        37x38x83 cm         7.14
# 1      Online  Not Returned           9.51         8x65x86 cm        12.48
# 2    In-Store      Returned           7.35        17x71x89 cm        14.27
#
#      SalesRegion  PromotionCode  PaymentMethod
# 0  North America         SALE15  Bank Transfer
# 1           Asia         SALE15  Bank Transfer
# 2  North America      DISCOUNT5  Bank Transfer
#
# [3 rows x 24 columns]

# %%
# Información general del DataFrame retail2
retail2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          420 non-null    float64
#  1   StockCode          440 non-null    object
#  2   Description        413 non-null    object
#  3   Quantity           440 non-null    object
#  4   InvoiceDate        435 non-null    object
#  5   UnitPrice          440 non-null    object
#  6   CustomerID         440 non-null    int64
#  7   Country            439 non-null    object
#  8   CustomerName       440 non-null    object
#  9   Email              440 non-null    object
#  10  Address            440 non-null    object
#  11  PhoneNumber        440 non-null    object
#  12  Category           440 non-null    object
#  13  Supplier           440 non-null    object
#  14  StockLevel         440 non-null    int64
#  15  Discount           440 non-null    float64
#  16  SaleChannel        440 non-null    object
#  17  ReturnStatus       440 non-null    object
#  18  ProductWeight      440 non-null    float64
#  19  ProductDimensions  440 non-null    object
#  20  ShippingCost       440 non-null    float64
#  21  SalesRegion        440 non-null    object
#  22  PromotionCode      359 non-null    object
#  23  PaymentMethod      440 non-null    object
# dtypes: float64(4), int64(2), object(18)
# memory usage: 82.6+ KB

# %% [markdown]
# # Limpieza de datos : Columna InvoiceNo

# %% [markdown]
# - Rellenar los valores Nulos con un valor especifico con 0
# - Cambiar los datos flotantes a números enteros

# %%
# Suponiendo que retail2_df ya está definido
min_invoice = retail2_df['InvoiceNo'].min()
max_invoice = retail2_df['InvoiceNo'].max()

print(f"El número de factura empieza en: {min_invoice}")
print(f"El número de factura finaliza en: {max_invoice}")
# Out:
# El número de factura empieza en: 536365.0
# El número de factura finaliza en: 536744.0

# %%
# Suponiendo que retail2_df ya está definido
expected_range = set(range(536365, 536744))
actual_values = set(retail2_df['InvoiceNo'].dropna().astype(int))
missing_values = expected_range - actual_values

print(f"Valores faltantes en la columna InvoiceNo: {sorted(missing_values)}")
# Out:
# Valores faltantes en la columna InvoiceNo: [536397, 536422, 536497, 536508, 536586, 536596, 536602, 536603, 536612, 536625, 536642, 536659, 536666, 536685, 536714]

# %%
# Rellenar valores nulos con un número específico, por ejemplo, 0
retail2_df['InvoiceNo'] = retail2_df['InvoiceNo'].fillna(0)

# Convertir la columna a tipo entero
retail2_df['InvoiceNo'] = retail2_df['InvoiceNo'].astype(int)

# Verificar el cambio
print(retail2_df['InvoiceNo'].head())
# Out:
# 0    536578
# 1    536446
# 2    536633
# 3    536522
# 4         0
# Name: InvoiceNo, dtype: int64

# %%
# Suponiendo que retail2_df ya está definido y que has rellenado los valores nulos con 0
retail2_df['InvoiceNo'] = retail2_df['InvoiceNo'].fillna(0)
retail2_df['InvoiceNo'] = retail2_df['InvoiceNo'].astype(int)

# Filtrar y mostrar los valores que están en 0 en la columna InvoiceNo
cero_values = retail2_df[retail2_df['InvoiceNo'] == 0]
print(cero_values['InvoiceNo'])
# Out:
# 4      0
# 24     0
# 25     0
# 52     0
# 78     0
# 91     0
# 102    0
# 165    0
# 167    0
# 208    0
# 209    0
# 218    0
# 251    0
# 253    0
# 297    0
# 299    0
# 304    0
# 366    0
# 395    0
# 412    0
# Name: InvoiceNo, dtype: int64

# %%
# Diccionario con los índices y los nuevos valores de InvoiceNo
nuevos_valores = {
    91: 536397,
    366: 536422,
    4: 536497,
    102: 536508,
    304: 536524,
    297: 536570,
    25: 536586,
    253: 536596,
    251: 536603,
    165: 536612,
    208: 536625,
    218: 536642,
    299: 536659,
    209: 536666,
    395: 536685,
    167: 536698,
    24: 536714,
    78: 536653,
    52: 536730,
    412: 536384
}

# Asignar los nuevos valores
for index, new_value in nuevos_valores.items():
    retail2_df.loc[index, 'InvoiceNo'] = new_value

# %%
# Suponiendo que retail2_df ya está definido
expected_range = set(range(536365, 536744))
actual_values = set(retail2_df['InvoiceNo'].dropna().astype(int))
missing_values = expected_range - actual_values

print(f"Valores faltantes en la columna InvoiceNo: {sorted(missing_values)}")
# Out:
# Valores faltantes en la columna InvoiceNo: [536602]

# %%
# Crear un DataFrame con el valor faltante
missing_value = pd.DataFrame({'InvoiceNo': [536602]})

# Concatenar este nuevo DataFrame con el DataFrame original
retail2_df = pd.concat([retail2_df, missing_value], ignore_index=True)

# Ordenar el DataFrame por la columna InvoiceNo de menor a mayor
retail2_df = retail2_df.sort_values(by='InvoiceNo')

# Verificar nuevamente los valores faltantes en el rango especificado
expected_range = set(range(536365, 536745))
actual_values = set(retail2_df['InvoiceNo'].dropna().astype(int))
missing_values = expected_range - actual_values

print(f"Valores faltantes en la columna InvoiceNo: {sorted(missing_values)}")
# Out:
# Valores faltantes en la columna InvoiceNo: []

# %%
# Ajustar las opciones de pandas para mostrar todas las filas
pd.set_option('display.max_rows', None)

# Mostrar todos los datos de la columna InvoiceNo
print(retail2_df['InvoiceNo'].head(10))
# Out:
# 47     536365
# 38     536365
# 302    536365
# 361    536365
# 307    536365
# 175    536365
# 313    536365
# 211    536366
# 31     536366
# 86     536367
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# # Limpieza de datos : Columna InvoiceDate

# %% [markdown]
# - Se verifica los datos que contiene la columna.
# - Eliminar la palabra Date:
# - Se unifica a una sola fecha a la 12/01/2010 ya que en el csv se observa que los datos de las ventas corresponden a una misma fecha cambiamos 01/12/2010, 01/01/1900, 01/01/2050, 01/12/2010, 30/12/2010, 12/1/2010, 30/02/2010
# - Intentar convertir la columna InvoiceDate a tipo datetime con el formato correcto.

# %%
# Verificación de datos y se observan en orden 
retail2_df = retail2_df.sort_values(by='InvoiceDate') 
print(retail2_df['InvoiceDate'].unique())
# Out:
# ['01-12-2010 09:47' '01-12-2010 10:09' '01-12-2010 11:27'
#  '01-12-2010 13:42' '01/01/1900 00:00' '01/01/2050 00:00'
#  '01/12/2010 25:61' '12/01/2010 09:08' '12/01/2010 10:41'
#  '12/01/2010 10:52' '12/01/2010 12:22' '12/01/2010 14:55'
#  '12/1/2010 10:00' '12/1/2010 10:01' '12/1/2010 10:03' '12/1/2010 10:04'
#  '12/1/2010 10:05' '12/1/2010 10:06' '12/1/2010 10:07' '12/1/2010 10:08'
#  '12/1/2010 10:10' '12/1/2010 10:12' '12/1/2010 10:13' '12/1/2010 10:15'
#  '12/1/2010 10:16' '12/1/2010 10:17' '12/1/2010 10:18' '12/1/2010 10:20'
#  '12/1/2010 10:21' '12/1/2010 10:22' '12/1/2010 10:23' '12/1/2010 10:24'
#  '12/1/2010 10:26' '12/1/2010 10:27' '12/1/2010 10:28' '12/1/2010 10:29'
#  '12/1/2010 10:30' '12/1/2010 10:31' '12/1/2010 10:32' '12/1/2010 10:33'
#  '12/1/2010 10:35' '12/1/2010 10:36' '12/1/2010 10:37' '12/1/2010 10:38'
#  '12/1/2010 10:39' '12/1/2010 10:40' '12/1/2010 10:42' '12/1/2010 10:44'
#  '12/1/2010 10:46' '12/1/2010 10:47' '12/1/2010 10:48' '12/1/2010 10:49'
#  '12/1/2010 10:50' '12/1/2010 10:51' '12/1/2010 10:52' '12/1/2010 10:53'
#  '12/1/2010 10:54' '12/1/2010 10:55' '12/1/2010 10:56' '12/1/2010 10:57'
#  '12/1/2010 10:58' '12/1/2010 10:59' '12/1/2010 11:00' '12/1/2010 11:01'
#  '12/1/2010 11:02' '12/1/2010 11:03' '12/1/2010 11:04' '12/1/2010 11:06'
#  '12/1/2010 11:07' '12/1/2010 11:08' '12/1/2010 11:09' '12/1/2010 11:10'
#  '12/1/2010 11:11' '12/1/2010 11:12' '12/1/2010 11:13' '12/1/2010 11:14'
#  '12/1/2010 11:15' '12/1/2010 11:16' '12/1/2010 11:17' '12/1/2010 11:18'
#  '12/1/2010 9:29' '12/1/2010 9:30' '12/1/2010 9:31' '12/1/2010 9:32'
#  '12/1/2010 9:33' '12/1/2010 9:34' '12/1/2010 9:35' '12/1/2010 9:36'
#  '12/1/2010 9:38' '12/1/2010 9:39' '12/1/2010 9:40' '12/1/2010 9:41'
#  '12/1/2010 9:42' '12/1/2010 9:43' '12/1/2010 9:44' '12/1/2010 9:45'
#  '12/1/2010 9:46' '12/1/2010 9:48' '12/1/2010 9:49' '12/1/2010 9:50'
#  '12/1/2010 9:51' '12/1/2010 9:52' '12/1/2010 9:53' '12/1/2010 9:54'
#  '12/1/2010 9:56' '12/1/2010 9:57' '12/1/2010 9:58' '12/1/2010 9:59'
#  '30/02/2010 00:00' nan]

# %%
# Intentar convertir la columna InvoiceDate a tipo datetime con el formato correcto
retail2_df['InvoiceDate'] = pd.to_datetime(retail2_df['InvoiceDate'], format='%d/%m/%Y %H:%M', errors='coerce')

# Definir la fecha válida
valid_date = pd.to_datetime('12/01/2010', format='%d/%m/%Y')

# Filtrar las fechas que no coinciden con la fecha válida (manteniendo la hora)
invalid_dates = retail2_df[retail2_df['InvoiceDate'].dt.date != valid_date.date()]

# Mostrar únicamente las columnas InvoiceNo y InvoiceDate de las filas con fechas inválidas
print(invalid_dates[['InvoiceNo', 'InvoiceDate']])

# Contar las filas con fechas inválidas
invalid_count = invalid_dates.shape[0]
print(f"Cantidad de filas con fechas inválidas: {invalid_count}")
# Out:
#      InvoiceNo InvoiceDate
# 223     536417         NaT
# 32      536439         NaT
# 114     536517         NaT
# 396     536652         NaT
# 100     536588  1900-01-01
# 83      536598  1900-01-01
# 338     536380  1900-01-01
# 268     536636  1900-01-01
# 352     536473  1900-01-01
# 139     536687  1900-01-01
# 186     536407  1900-01-01
# 358     536425  1900-01-01
# 160     536544  1900-01-01
# 87      536677  1900-01-01
# 78      536653  2050-01-01
# 104     536564  2050-01-01
# 69      536564  2050-01-01
# 34      536651  2050-01-01
# 6       536707  2050-01-01
# 173     536519  2050-01-01
# 380     536444  2050-01-01
# 142     536374  2050-01-01
# 279     536709  2050-01-01
# 241     536530  2050-01-01
# 308     536449  2050-01-01
# 174     536390         NaT
# 16      536676         NaT
# 430     536370         NaT
# 52      536730         NaT
# 285     536669         NaT
# 82      536432         NaT
# 318     536673         NaT
# 90      536605         NaT
# 281     536630         NaT
# 105     536630         NaT
# 58      536455         NaT
# 412     536384         NaT
# 17      536375         NaT
# 421     536369         NaT
# 23      536628         NaT
# 261     536464         NaT
# 415     536375         NaT
# 346     536441         NaT
# 342     536388         NaT
# 195     536475         NaT
# 303     536568         NaT
# 49      536584         NaT
# 440     536602         NaT
# 231     536604         NaT
# Cantidad de filas con fechas inválidas: 49

# %%
# Suponiendo que ya has convertido la columna InvoiceDate a datetime
retail2_df['InvoiceDate'] = pd.to_datetime(retail2_df['InvoiceDate'], errors='coerce', dayfirst=True)

# Crear un diccionario con las fechas corregidas utilizanzo  InvoiceNo
fechas_actualizadas = {
    536417: '12/01/2010 9:47',
    536439: '12/01/2010 10:09',
    536517: '12/01/2010 11:27',
    536652: '12/01/2010 13:42',
    536588: '12/01/2010 12:38',
    536598: '12/01/2010 12:48',
    536380: '12/01/2010 9:10',
    536636: '12/01/2010 13:26',
    536473: '12/01/2010 10:43',
    536687: '12/01/2010 14:17',
    536407: '12/01/2010 9:37',
    536425: '12/01/2010 9:55',
    536544: '12/01/2010 11:54',
    536677: '12/01/2010 14:07',
    536653: '12/01/2010 13:44',
    536564: '12/01/2010 12:14',
    536651: '12/01/2010 13:41',
    536707: '12/01/2010 14:37',
    536519: '12/01/2010 11:29',
    536444: '12/01/2010 10:14',
    536374: '12/01/2010 9:04',
    536709: '12/01/2010 14:39',
    536530: '12/01/2010 11:40',
    536449: '12/01/2010 10:19',
    536390: '12/01/2010 9:20',
    536676: '12/01/2010 14:06',
    536370: '12/01/2010 9:00',
    536730: '12/01/2010 15:00',
    536669: '12/01/2010 13:59',
    536432: '12/01/2010 10:02',
    536673: '12/01/2010 14:03',
    536605: '12/01/2010 12:55',
    536630: '12/01/2010 13:20',
    536455: '12/01/2010 10:25',
    536384: '12/01/2010 9:14',
    536375: '12/01/2010 9:05',
    536369: '12/01/2010 8:36',
    536628: '12/01/2010 13:18',
    536464: '12/01/2010 10:34',
    536441: '12/01/2010 10:11',
    536388: '12/01/2010 9:18',
    536475: '12/01/2010 10:45',
    536568: '12/01/2010 12:18',
    536584: '12/01/2010 12:34',
    536602: '12/01/2010 12:52',
    536604: '12/01/2010 12:54'
}

# Actualizar las fechas en el DataFrame
for invoice_no, fecha in fechas_actualizadas.items():
    retail2_df.loc[retail2_df['InvoiceNo'] == invoice_no, 'InvoiceDate'] = pd.to_datetime(fecha, dayfirst=True)

# Formatear las fechas al formato deseado
retail2_df['InvoiceDate'] = retail2_df['InvoiceDate'].dt.strftime('%d/%m/%Y %H:%M')

# Identificar las fechas que no se pudieron convertir
fechas_invalidas = retail2_df[retail2_df['InvoiceDate'].isna()]

# Mostrar las fechas inválidas
print("Fechas inválidas:")
# Out:
# Fechas inválidas:

# %%
# Verificación de datos y se observan en orden 
retail2_df = retail2_df.sort_values(by='InvoiceDate') 
print(retail2_df['InvoiceDate'].unique())
# Out:
# ['12/01/2010 08:26' '12/01/2010 08:28' '12/01/2010 08:34'
#  '12/01/2010 08:35' '12/01/2010 08:36' '12/01/2010 09:00'
#  '12/01/2010 09:01' '12/01/2010 09:02' '12/01/2010 09:03'
#  '12/01/2010 09:04' '12/01/2010 09:05' '12/01/2010 09:06'
#  '12/01/2010 09:07' '12/01/2010 09:08' '12/01/2010 09:09'
#  '12/01/2010 09:10' '12/01/2010 09:11' '12/01/2010 09:12'
#  '12/01/2010 09:13' '12/01/2010 09:14' '12/01/2010 09:15'
#  '12/01/2010 09:16' '12/01/2010 09:17' '12/01/2010 09:18'
#  '12/01/2010 09:19' '12/01/2010 09:20' '12/01/2010 09:21'
#  '12/01/2010 09:22' '12/01/2010 09:23' '12/01/2010 09:24'
#  '12/01/2010 09:25' '12/01/2010 09:26' '12/01/2010 09:27'
# %%
# Verificación de datos y se observan en orden 
retail2_df = retail2_df.sort_values(by='Description') 
print(retail2_df['Description'].unique())
# Out:
# ['  BAKING SET 9 PIECE RETROSPOT  ' '  BOX OF VINTAGE ALPHABET BLOCKS  '
#  '  BOX OF VINTAGE JIGSAW BLOCKS  ' '  CHOCOLATE HOT WATER BOTTLE  '
#  '  CREAM CUPID HEARTS COAT HANGER  ' '  HAND WARMER RED POLKA DOT  '
#  '  HAND WARMER UNION JACK  ' '  HOME BUILDING BLOCK WORD  '
#  '  JUMBO BAG RED RETROSPOT  ' '  PACK OF 12 BLUE RETROSPOT TISSUES  '
#  '  PACK OF 6 SMALL FRUIT STRAWS  ' "  POPPY'S PLAYHOUSE BEDROOM  "
#  "  POPPY'S PLAYHOUSE KITCHEN  " '  RED HARMONICA IN BOX  '
#  '  RED TOADSTOOL LED NIGHT LIGHT  ' '  RETROSPOT TEA SET CERAMIC 11 PC  '
#  '  WHITE METAL LANTERN  ' '  nan  ' '***BAKING SET 9 PIECE RETROSPOT***'
#  '***CHOCOLATE HOT WATER BOTTLE***' '***DOORMAT NEW ENGLAND***'
#  '***FELTCRAFT PRINCESS CHARLOTTE DOLL***'
#  '***HAND WARMER RED POLKA DOT***' '***IVORY KNITTED MUG COSY***'
#  '***JAM MAKING SET WITH JARS***' "***POPPY'S PLAYHOUSE BEDROOM***"
#  "***POPPY'S PLAYHOUSE KITCHEN***" '***RED GLASS CANDLE HOLDER STAR***'
#  '***RED TOADSTOOL LED NIGHT LIGHT***'
#  '***RED WOOLLY HOTTIE WHITE HEART.***' '***SCANDINAVIAN REDS RIBBONS***'
#  '***WHITE METAL LANTERN***' '***nan***'
#  '***striped charlie+lola charlotte bag***'
#  'ASSORTED COLOUR BIRD ORNAMENT' 'BAKING SET 9 PIECE RETROSPOT'
#  'BLUE HARMONICA IN BOX' 'BLUE HARMONICA IN BOX: details'
#  'BOX OF 6 ASSORTED COLOUR TEASPOONS' 'BOX OF VINTAGE ALPHABET BLOCKS'
#  'BOX OF VINTAGE ALPHABET BLOCKS: details' 'BOX OF VINTAGE JIGSAW BLOCKS'
#  'CHOCOLATE  HOT  WATER  BOTTLE' 'CHOCOLATE HOT WATER BOTTLE'
#  'CHOCOLATE HOT WATER BOTTLE: details' 'COFFEE MUG APPLES DESIGN'
#  'CREAM CUPID HEARTS COAT HANGER' 'DOORMAT NEW ENGLAND'
#  'FELTCRAFT PRINCESS CHARLOTTE DOLL' 'GLASS JAR DAISY FRESH COTTON WOOL'
#  'GLASS STAR FROSTED T-LIGHT HOLDER' 'HAND  WARMER  RED  POLKA  DOT'
#  'HAND WARMER RED POLKA DOT' 'HAND WARMER UNION JACK'
#  'HANGING STAR WITH BELLS' 'HEART  OF  WICKER  LARGE'
#  'HOME BUILDING BLOCK WORD' 'IVORY KNITTED MUG COSY'
#  'IVORY KNITTED MUG COSY: details' 'InvalidDescription123'
#  'JAM MAKING SET WITH JARS' 'JUMBO BAG PINK POLKADOT'
#  'KNITTED UNION FLAG HOT WATER BOTTLE' 'LOVE  BUILDING  BLOCK  WORD'
#  'LOVE BUILDING BLOCK WORD' 'PACK OF 12 PINK POLKADOT TISSUES'
#  'PACK OF 12 RED RETROSPOT TISSUES' 'PACK OF 6 SMALL FRUIT STRAWS'
#  "POPPY'S  PLAYHOUSE  BEDROOM" "POPPY'S  PLAYHOUSE  KITCHEN"
#  "POPPY'S PLAYHOUSE BEDROOM" "POPPY'S PLAYHOUSE KITCHEN"
#  'RECIPE BOX WITH METAL HEART' 'RED  HARMONICA IN BOX'
#  'RED  WOOLLY  HOTTIE  WHITE  HEART.' 'RED HARMONICA IN BOX'
#  'RED TOADSTOOL LED NIGHT LIGHT' 'RED WOOLLY HOTTIE WHITE HEART.'
#  'RETROSPOT TEA SET CERAMIC 11 PC' 'SCANDINAVIAN  REDS  RIBBONS'
#  'SCANDINAVIAN REDS RIBBONS' 'SCANDINAVIAN REDS RIBBONS: details'
#  'SET 2 TEA TOWELS I LOVE LONDON' 'SET 7 BABUSHKA NESTING BOXES'
#  'SET OF 3 CAKE TINS PANTRY DESIGN' 'SET OF 7 BABUSHKA NESTING BOXES'
#  'STRIPED CHARLIE+LOLA CHARLOTTE BAG'
#  'STRIPED CHARLIE+LOLA CHARLOTTE BAG: details' 'WHITE  METAL  LANTERN'
#  'WHITE HANGING HEART T-LIGHT HOLDER' 'WHITE METAL LANTERN'
#  '["description": "BLUE HARMONICA IN BOX"]'
#  '["description": "BOX OF 6 ASSORTED COLOUR TEASPOONS"]'
#  '["description": "BOX OF VINTAGE ALPHABET BLOCKS"]'
#  '["description": "HAND WARMER UNION JACK"]'
#  '["description": "HOME BUILDING BLOCK WORD"]'
#  '["description": "JAM MAKING SET WITH JARS"]'
#  '["description": "JAM MAKING SET WITH JARS: details"]'
#  '["description": "RED HARMONICA IN BOX"]'
#  '["description": "RETROSPOT TEA SET CERAMIC 11 PC"]'
#  '["description": "WHITE METAL LANTERN"]' 'assorted colour bird ornament'
#  'ivory  knitted  mug  cosy' 'jam making set with jars'
#  'knitted union flag hot water bottle' "poppy's playhouse kitchen"
#  'set 2 tea towels i love london' 'set 7 babushka nesting boxes'
#  'striped charlie+lola charlotte bag' 'white metal lantern'
#  '{"DESCRIPTION": ["HAND WARMER RED POLKA DOT"]}'
#  '{"description": "ASSORTED COLOUR BIRD ORNAMENT"}'
#  '{"description": "BAKING SET 9 PIECE RETROSPOT"}'
#  '{"description": "BLUE HARMONICA IN BOX"}'
#  '{"description": "BOX OF 6 ASSORTED COLOUR TEASPOONS"}'
#  '{"description": "HAND WARMER UNION JACK"}'
#  '{"description": "RECIPE BOX WITH METAL HEART"}'
#  '{"description": "RED TOADSTOOL LED NIGHT LIGHT"}'
#  '{"description": "SCANDINAVIAN REDS RIBBONS"}'
#  '{"description": "SET 2 TEA TOWELS I LOVE LONDON"}'
#  '{"description": "WHITE HANGING HEART T-LIGHT HOLDER"}'
#  '{"description": "WHITE METAL LANTERN"}'
#  '{"description": "{"description": "RED GLASS CANDLE HOLDER STAR"}"}'
#  '{"description": ["BLUE HARMONICA IN BOX"]}'
#  '{"description": ["BOX OF VINTAGE JIGSAW BLOCKS"]}'
#  '{"description": ["HAND WARMER RED POLKA DOT"]}'
#  '{"description": ["JAM MAKING SET WITH JARS"]}'
#  '{"description": ["PACK OF 12 RED RETROSPOT TISSUES: details"]}' nan]

# %%
# Eliminar de la columna caracteres *, [, ', {, y "
retail2_df['Description']=retail2_df['Description'].str.replace(r'[\*\[\{\'\"\}\]\:\.]','',regex=True).str.strip()

# Eliminar las palabras 'description:', 'DETAILS' y 'INVALIDDESCRIPTION123'
retail2_df['Description'] = retail2_df['Description'].str.replace(r'description:|DETAILS|INVALIDDESCRIPTION123|DESCRIPTION', '', regex=True).str.strip()

# Convertir a mayúsculas el texto en la columna 'Description'
retail2_df['Description'] = retail2_df['Description'].str.upper()


# Ordenar alfabéticamente los datos de la columna 'Description'
retail2_df = retail2_df.sort_values(by='Description')

# Eliminar espacios extra en la columna 'Description'
retail2_df['Description'] = retail2_df['Description'].str.replace(r'\s+', ' ', regex=True).str.strip()

# Mostrar las primeras filas del DataFrame después de la limpieza
print(retail2_df['Description'].unique())
# Out:
# ['ASSORTED COLOUR BIRD ORNAMENT' 'BAKING SET 9 PIECE RETROSPOT'
#  'BLUE HARMONICA IN BOX' 'BLUE HARMONICA IN BOX DETAILS'
#  'BOX OF 6 ASSORTED COLOUR TEASPOONS' 'BOX OF VINTAGE ALPHABET BLOCKS'
#  'BOX OF VINTAGE ALPHABET BLOCKS DETAILS' 'BOX OF VINTAGE JIGSAW BLOCKS'
#  'CHOCOLATE HOT WATER BOTTLE' 'CHOCOLATE HOT WATER BOTTLE DETAILS'
#  'COFFEE MUG APPLES DESIGN' 'CREAM CUPID HEARTS COAT HANGER'
#  'DESCRIPTION ASSORTED COLOUR BIRD ORNAMENT'
#  'DESCRIPTION BAKING SET 9 PIECE RETROSPOT'
#  'DESCRIPTION BLUE HARMONICA IN BOX'
#  'DESCRIPTION BOX OF 6 ASSORTED COLOUR TEASPOONS'
#  'DESCRIPTION BOX OF VINTAGE ALPHABET BLOCKS'
#  'DESCRIPTION BOX OF VINTAGE JIGSAW BLOCKS'
#  'DESCRIPTION DESCRIPTION RED GLASS CANDLE HOLDER STAR'
#  'DESCRIPTION HAND WARMER RED POLKA DOT'
#  'DESCRIPTION HAND WARMER UNION JACK'
#  'DESCRIPTION HOME BUILDING BLOCK WORD'
#  'DESCRIPTION JAM MAKING SET WITH JARS'
#  'DESCRIPTION JAM MAKING SET WITH JARS DETAILS'
#  'DESCRIPTION PACK OF 12 RED RETROSPOT TISSUES DETAILS'
#  'DESCRIPTION RECIPE BOX WITH METAL HEART'
#  'DESCRIPTION RED HARMONICA IN BOX'
#  'DESCRIPTION RED TOADSTOOL LED NIGHT LIGHT'
#  'DESCRIPTION RETROSPOT TEA SET CERAMIC 11 PC'
#  'DESCRIPTION SCANDINAVIAN REDS RIBBONS'
#  'DESCRIPTION SET 2 TEA TOWELS I LOVE LONDON'
#  'DESCRIPTION WHITE HANGING HEART T-LIGHT HOLDER'
#  'DESCRIPTION WHITE METAL LANTERN' 'DOORMAT NEW ENGLAND'
#  'FELTCRAFT PRINCESS CHARLOTTE DOLL' 'GLASS JAR DAISY FRESH COTTON WOOL'
#  'GLASS STAR FROSTED T-LIGHT HOLDER' 'HAND WARMER RED POLKA DOT'
#  'HAND WARMER UNION JACK' 'HANGING STAR WITH BELLS'
#  'HEART OF WICKER LARGE' 'HOME BUILDING BLOCK WORD'
#  'INVALIDDESCRIPTION123' 'IVORY KNITTED MUG COSY'
#  'IVORY KNITTED MUG COSY DETAILS' 'JAM MAKING SET WITH JARS'
#  'JUMBO BAG PINK POLKADOT' 'JUMBO BAG RED RETROSPOT'
#  'KNITTED UNION FLAG HOT WATER BOTTLE' 'LOVE BUILDING BLOCK WORD' 'NAN'
#  'PACK OF 12 BLUE RETROSPOT TISSUES' 'PACK OF 12 PINK POLKADOT TISSUES'
#  'PACK OF 12 RED RETROSPOT TISSUES' 'PACK OF 6 SMALL FRUIT STRAWS'
#  'POPPYS PLAYHOUSE BEDROOM' 'POPPYS PLAYHOUSE KITCHEN'
#  'RECIPE BOX WITH METAL HEART' 'RED HARMONICA IN BOX'
#  'RED WOOLLY HOTTIE WHITE HEART' 'RED GLASS CANDLE HOLDER STAR'
#  'RED TOADSTOOL LED NIGHT LIGHT' 'RETROSPOT TEA SET CERAMIC 11 PC'
#  'SCANDINAVIAN REDS RIBBONS' 'SCANDINAVIAN REDS RIBBONS DETAILS'
#  'SET 2 TEA TOWELS I LOVE LONDON' 'SET 7 BABUSHKA NESTING BOXES'
#  'SET OF 3 CAKE TINS PANTRY DESIGN' 'SET OF 7 BABUSHKA NESTING BOXES'
#  'STRIPED CHARLIE+LOLA CHARLOTTE BAG'
#  'STRIPED CHARLIE+LOLA CHARLOTTE BAG DETAILS' 'WHITE METAL LANTERN'
#  'WHITE HANGING HEART T-LIGHT HOLDER' nan]

# %%
# Contar los valores vacíos en la columna 'Description'
missing_values_count = retail2_df['Description'].isnull().sum()

# Filtrar las filas con valores vacíos en 'Description'
missing_values = retail2_df[retail2_df['Description'].isnull()]

# Seleccionar solo las columnas 'InvoiceNo', 'StockCode' y 'Description'
filtered_missing_values = missing_values[['InvoiceNo', 'StockCode', 'Description']]

# Mostrar el total de valores vacíos
print(f"Hay {missing_values_count} valores vacíos en la columna 'Description'.")

# Mostrar las filas filtradas
print("Filas con valores vacíos en 'Description':")
print(filtered_missing_values)
# Out:
# Hay 28 valores vacíos en la columna 'Description'.
# Filas con valores vacíos en 'Description':
#      InvoiceNo                                          StockCode Description
# 360     536367                                              84879         NaN
# 319     536378                                              22634         NaN
# 322     536379                          SCANDINAVIAN REDS RIBBONS         NaN
# 309     536387                                              21756         NaN
# 401     536401                                              22386         NaN
# 314     536415  {"description": ["RED WOOLLY HOTTIE WHITE HEAR...         NaN
# 223     536417                                              21730         NaN
# 298     536434                              RED  HARMONICA IN BOX         NaN
# 243     536438                                              22632         NaN
# 32      536439                                              21914         NaN
# 213     536451                 STRIPED CHARLIE+LOLA CHARLOTTE BAG         NaN
# 276     536471                                              22633         NaN
# 115     536477                                              22310         NaN
# 369     536506                           JAM MAKING SET WITH JARS         NaN
# 130     536554                                              22632         NaN
# 9       536576                                              22749         NaN
# 440     536602                                                NaN         NaN
# 203     536611                                              21724         NaN
# 227     536611                                              21724         NaN
# 345     536623                                              21724         NaN
# 208     536625                                             85123A         NaN
# 136     536639                 BOX OF 6 ASSORTED COLOUR TEASPOONS         NaN
# 316     536662                               RED HARMONICA IN BOX         NaN
# 182     536674                                              22745         NaN
# 145     536706                                              22960         NaN
# 43      536721                                              22634         NaN
# 169     536730                                              22752         NaN
# 292     536743                           LOVE BUILDING BLOCK WORD         NaN

# %% [markdown]
# # Limpieza de datos columna :StockCode
#
# - Limpieza de datos :Columna StockCode
# - Mirar los valores únicos de la columna
# - Unificar criterios de los códigos como: Eliminar las letras al final del numero del codigo para que no sean alfanumericos.
# - Identificar las filas de la columna StockCode contiene descripciones en lugar de códigos
# - Contar los valores nulos en la columna 'StockCode'
# - Rellenar los valores faltantes en la columna 'StockCode' basados en la columna 'Description' Creando un diccionario de los valores y descripciones con Stockcode y Description
# - Verificar valores faltantes nuevamente
# - Queda un valor faltante crear un diccionario con ese valor
# - Verificar que no quede ningun valor faltante

# %%
# Verificación de datos y se observan en orden 
retail2_df = retail2_df.sort_values(by='InvoiceDate') 
print(retail2_df['StockCode'].unique())
# Out:
# ['22752' '71053' '84406B' '21730' '85123A' '84029E' '84029G' '22632'
#  '22633' '22745' '22749' '22623' '84969' '21755' '22748' '21754' '22622'
#  '84879' '22310' '21777' '84988' '21756' '21724' '21723' '22111' '21914'
#  '21731' '22960' '22139' '22112' '22634' 'SCANDINAVIAN REDS RIBBONS'
#  '22725' '22624' '22570' '22571' '22754' '22386' '85099B' '84907B'
#  '84907C' '84907A' '22751' '22382' '22469' '22384'
#  '{"description": ["RED WOOLLY HOTTIE WHITE HEART.: details"]}'
#  'RED  HARMONICA IN BOX' 'STRIPED CHARLIE+LOLA CHARLOTTE BAG'
#  'JAM MAKING SET WITH JARS' 'SET 2 TEA TOWELS I LOVE LONDON' nan
#  'HAND WARMER RED POLKA DOT' 'BOX OF 6 ASSORTED COLOUR TEASPOONS'
#  'RED HARMONICA IN BOX' 'LOVE BUILDING BLOCK WORD']

# %%
# Eliminar espacios en blanco al principio y al final de los valores en la columna 'StockCode'
retail2_df['StockCode'] = retail2_df['StockCode'].str.strip()

# Mostrar el DataFrame para verificar los cambios
print(retail2_df['StockCode'].head())
# Out:
# 302     22752
# 361     71053
# 313    84406B
# 175     21730
# 307    85123A
# Name: StockCode, dtype: object

# %%
retail2_df = retail2_df.sort_values(by='InvoiceDate') 
print(retail2_df['StockCode'].unique())
# Out:
# ['22752' '71053' '84406B' '21730' '85123A' '84029E' '84029G' '22632'
#  '22633' '22310' '84879' '22622' '21754' '22748' '84969' '22623' '22749'
#  '22745' '21755' '21777' '84988' '21756' '21723' '21724' '22111' '21914'
#  '21731' '22960' '22139' '22112' '22634' 'SCANDINAVIAN REDS RIBBONS'
#  '22725' '22624' '22570' '22571' '22754' '22386' '85099B' '84907B'
#  '84907C' '84907A' '22751' '22382' '22469' '22384'
#  '{"description": ["RED WOOLLY HOTTIE WHITE HEART.: details"]}'
#  'RED  HARMONICA IN BOX' 'STRIPED CHARLIE+LOLA CHARLOTTE BAG'
#  'JAM MAKING SET WITH JARS' 'SET 2 TEA TOWELS I LOVE LONDON' nan
#  'HAND WARMER RED POLKA DOT' 'BOX OF 6 ASSORTED COLOUR TEASPOONS'
#  'RED HARMONICA IN BOX' 'LOVE BUILDING BLOCK WORD']

# %%
# Función para mover descripciones de 'StockCode' a 'Description'
def move_descriptions(row):
    if pd.isna(row['Description']) and isinstance(row['StockCode'], str):
        if row['StockCode'].startswith('{"description":'):
            return eval(row['StockCode'])['description'][0]
        else:
            return row['StockCode']
    return row['Description']

# Aplicar la función para actualizar la columna 'Description'
retail2_df['Description'] = retail2_df.apply(move_descriptions, axis=1)

# Eliminar las filas con 'nan' en la columna 'Description'
retail2_df = retail2_df[~retail2_df['Description'].isin(['nan', '***nan***'])]

# Mostrar solo las columnas 'StockCode' y 'Description'
retail2_df
# Out:
#      InvoiceNo                                          StockCode  \
# 302     536365                                              22752
# 361     536365                                              71053
# 313     536365                                             84406B
# 175     536365                                              21730
# 307     536365                                             85123A
# 38      536365                                             84029E
# 47      536365                                             84029G
# 211     536366                                              22632
# 31      536366                                              22633
# 222     536367                                              22310
# 360     536367                                              84879
# 247     536367                                              22622
# 230     536367                                              21754
# 117     536367                                              22748
# 282     536367                                              84969
# 388     536367                                              22623
# 273     536367                                              22749
# 86      536367                                              22745
# 206     536367                                              21755
# 438     536368                                              21777
# 72      536368                                              84988
# 421     536369                                              21756
# 267     536370                                              21723
# 430     536370                                              21724
# 374     536370                                              22111
# 341     536371                                              71053
# 383     536371                                             85123A
# 10      536372                                              22632
# 30      536373                                              21914
# 142     536374                                              21731
# 415     536375                                              22960
# 17      536375                                              22960
# 312     536376                                              22139
# 11      536377                                              22112
# 319     536378                                              22634
# 322     536379                          SCANDINAVIAN REDS RIBBONS
# 338     536380                                              22112
# 79      536381                                              22752
# 68      536382                                              22725
# 48      536383                                              22624
# 116     536384                                              22570
# 412     536384                                              22570
# 284     536385                                              22571
# 417     536386                                              22749
# 309     536387                                              21756
# 342     536388                                              22745
# 347     536389                                              22748
# 174     536390                                              22752
# 214     536391                                              22633
# 133     536392                                              22632
# 183     536393                                              22111
# 245     536394                                              21724
# 99      536395                                              21723
# 437     536396                                              22623
# 179     536396                                              22623
# 91      536397                                              22622
# 385     536398                                              22754
# 63      536399                                              21754
# 336     536399                                              21754
# 403     536400                                              21755
# 401     536401                                              22386
# 350     536402                                             85099B
# 418     536403                                             84907B
# 121     536403                                             84907B
# 15      536404                                             84907C
# 386     536405                                             84907A
# 423     536406                                              22751
# 186     536407                                              22382
# 106     536408                                              22469
# 177     536409                                              22384
# 434     536409                                              22384
# 132     536410                                              22386
# 320     536411                                             85123A
# 249     536412                                              71053
# 332     536413                                             84406B
# 75      536414                                             84029G
# 314     536415  {"description": ["RED WOOLLY HOTTIE WHITE HEAR...
# 71      536416                                              22752
# 223     536417                                              21730
# 379     536418                                              22633
# 55      536419                                              22632
# 189     536420                                              84879
# 107     536421                                              22745
# 366     536422                                              22748
# 321     536423                                              22749
# 156     536424                                              22310
# 358     536425                                              84969
# 310     536426                                              22623
# 428     536427                                              22622
# 111     536427                                              22622
# 123     536428                                              21754
# 239     536429                                              21755
# 77      536430                                              21777
# 381     536430                                              21777
# 327     536431                                              84988
# 82      536432                                              21756
# 271     536433                                              22111
# 298     536434                              RED  HARMONICA IN BOX
# 40      536435                                              21723
# 199     536436                                             85123A
# 13      536437                                              71053
# 243     536438                                              22632
# 32      536439                                              21914
# 363     536440                                              21731
# 346     536441                                              22960
# 416     536442                                              22139
# 21      536443                                              22112
# 424     536443                                              22112
# 380     536444                                              22634
# 266     536445                                              22960
# 1       536446                                              21756
# 301     536447                                              22112
# 39      536448                                              22634
# 308     536449                                              22111
# 51      536450                                              21724
# 213     536451                 STRIPED CHARLIE+LOLA CHARLOTTE BAG
# 371     536452                                             85123A
# 337     536453                                              71053
# 405     536454                                              22632
# 58      536455                                              21914
# 413     536456                                              21731
# 18      536457                                              22960
# 399     536458                                              22139
# 290     536459                                              22112
# 8       536460                                              22634
# 264     536461                                              22111
# 176     536462                                              21724
# 325     536463                                              21723
# 261     536464                                             85123A
# 254     536465                                              71053
# 410     536466                                             84406B
# 14      536467                                             84029G
# 125     536468                                             84029E
# 359     536469                                              22752
# 419     536470                                              21730
# 276     536471                                              22633
# 439     536472                                              22632
# 352     536473                                              84879
# 330     536474                                              22745
# 195     536475                                              22748
# 219     536476                                              22749
# 115     536477                                              22310
# 180     536478                                              84969
# 159     536478                                              84969
# 73      536479                                              22623
# 37      536480                                              22622
# 250     536481                                              21754
# 376     536482                                              21755
# 113     536482                                              21755
# 45      536483                                              21777
# 357     536484                                              84988
# 109     536485                                              21756
# 201     536486                                              22111
# 144     536486                                              22111
# 12      536487                                              21724
# 171     536488                                              21723
# 259     536489                                             85123A
# 237     536490                                              71053
# 362     536491                                              22632
# 217     536492                                              21914
# 238     536493                                              21731
# 355     536494                                              22960
# 315     536495                                              22139
# 234     536496                                              22112
# 4       536497                                              22634
# 323     536498                                              22111
# 280     536499                                              21724
# 98      536500                                              21723
# 235     536501                                             85123A
# 414     536502                                              71053
# 53      536503                                              22632
# 126     536504                                              21914
# 190     536505                                              21731
# 134     536505                                              21731
# 369     536506                           JAM MAKING SET WITH JARS
# 158     536507                                              22139
# 102     536508                                              22112
# 64      536509                                              22634
# 263     536510                                              22111
# 141     536511                                              21724
# 384     536512                                              21723
# 317     536513                                             85123A
# 288     536514                                              71053
# 377     536515                                              22632
# 162     536516                                              21914
# 114     536517                                              21731
# 200     536518                                              22960
# 173     536519                                              22139
# 265     536520                                              22112
# 221     536521                                              22634
# 228     536521                                              22634
# 3       536522                                              22111
# 392     536523                                              21724
# 304     536524                                              21723
# 88      536524                                              21723
# 373     536525                                             85123A
# 433     536526                                              71053
# 236     536527                                             84406B
# 187     536528                                             84029G
# 426     536529                                             84029E
# 436     536529                                             84029E
# 241     536530                                              22752
# 375     536531                                              21730
# 166     536532                                              22633
# 163     536533                                              22632
# 28      536534                                              84879
# 289     536535                                              22745
# 378     536536                                              22748
# 95      536537                                              22749
# 194     536538                                              22310
# 46      536539                                              84969
# 185     536540                                              22623
# 42      536541                                              22622
# 394     536542                                              21754
# 274     536543                                              21755
# 33      536543                                              21755
# 160     536544                                              21777
# 286     536544                                              21777
# 229     536545                                              22960
# 120     536545                                              22960
# 181     536546                                              21756
# 269     536547                                              22112
# 287     536548                                              22634
# 210     536549                                              22111
# 367     536550                                              21724
# 406     536551                                              21723
# 192     536552                                             85123A
# 324     536552                                             85123A
# 293     536553                                              71053
# 130     536554                                              22632
# 348     536555                                              21914
# 344     536556                                              21731
# 420     536556                                              21731
# 143     536557                                              22960
# 184     536558                                              22139
# 270     536559                                              22112
# 61      536560                                              22634
# 258     536560                                              22634
# 215     536561                                              22111
# 157     536562                                              21724
# 390     536563                                              21723
# 69      536564                                             85123A
# 104     536564                                             85123A
# 161     536565                                              71053
# 198     536566                                             84406B
# 66      536567                                             84029G
# 303     536568                                             84029E
# 191     536569                                              22752
# 297     536570                                              21730
# 131     536570                                              21730
# 148     536571                                              22633
# 295     536572                                              22632
# 257     536573                                              84879
# 193     536574                                              22745
# 103     536575                                              22748
# 9       536576                                              22749
# 94      536577                                              22310
# 0       536578                                              84969
# 93      536579                                              22623
# 170     536579                                              22623
# 256     536580                                              22622
# 220     536580                                              22622
# 118     536581                                              21754
# 124     536582                                              21755
# 135     536583                                              21777
# 351     536583                                              21777
# 49      536584                     SET 2 TEA TOWELS I LOVE LONDON
# 432     536585                                              21756
# 25      536586                                              22111
# 22      536587                                              21724
# 100     536588                                              21723
# 62      536589                                             85123A
# 35      536590                                              71053
# 411     536591                                              22632
# 224     536592                                              21914
# 128     536593                                              21731
# 146     536594                                              22960
# 127     536595                                              22139
# 253     536596                                              22112
# 168     536597                                              22634
# 83      536598                                              22111
# 149     536599                                              21724
# 97      536600                                              21723
# 81      536601                                             85123A
# 440     536602                                                NaN
# 251     536603                                              22632
# 231     536604                                              21914
# 90      536605                                              21731
# 216     536606                                              22960
# 57      536607                                              22139
# 27      536608                                              22112
# 246     536609                                              22634
# 89      536610                                              22111
# 203     536611                                              21724
# 227     536611                                              21724
# 165     536612                                              21723
# 233     536613                                             85123A
# 305     536614                                              71053
# 272     536615                          HAND WARMER RED POLKA DOT
# 44      536616                                              21914
# 409     536617                                              21731
# 138     536618                                              22960
# 188     536619                                              22139
# 7       536620                                              22112
# 389     536621                                              22634
# 404     536622                                              22111
# 345     536623                                              21724
# 151     536624                                              21723
# 208     536625                                             85123A
# 340     536626                                              71053
# 294     536626                                              71053
# 207     536627                                             84406B
# 23      536628                                             84029G
# 262     536629                                             84029E
# 105     536630                                              22752
# 422     536630                                              22752
# 281     536630                                              22752
# 311     536631                                              21730
# 354     536632                                              22633
# 2       536633                                              22632
# 80      536634                                              84879
# 400     536635                                              22745
# 268     536636                                              22748
# 260     536637                                              22749
# 408     536638                                              22310
# 136     536639                 BOX OF 6 ASSORTED COLOUR TEASPOONS
# 76      536640                                              22623
# 29      536641                                              22622
# 218     536642                                              21754
# 205     536643                                              21755
# 155     536644                                              21777
# 164     536645                                              22960
# 326     536645                                              22960
# 368     536646                                              21756
# 108     536647                                              22112
# 70      536648                                              22634
# 204     536649                                              22111
# 240     536650                                              21724
# 34      536651                                              21723
# 396     536652                                             85123A
# 41      536653                                              71053
# 78      536653                                              71053
# 153     536654                                              22632
# 225     536655                                              21914
# 54      536656                                              21731
# 283     536657                                              22960
# 119     536658                                              22139
# 299     536659                                              22112
# 85      536660                                              22634
# 425     536660                                              22634
# 331     536661                                              22111
# 316     536662                               RED HARMONICA IN BOX
# 427     536663                                              21723
# 110     536664                                             85123A
# 393     536665                                              71053
# 209     536666                                             84406B
# 67      536667                                             84029G
# 202     536668                                             84029E
# 285     536669                                              22752
# 356     536670                                              21730
# 372     536671                                              22633
# 435     536672                                              22632
# 122     536672                                              22632
# 318     536673                                              84879
# 182     536674                                              22745
# 277     536675                                              22748
# 16      536676                                              22749
# 87      536677                                              22310
# 84      536678                                              84969
# 370     536679                                              22623
# 382     536680                                              22622
# 329     536681                                              21754
# 232     536682                                              21755
# 26      536683                                              21777
# 353     536684                                              84988
# 395     536685                                              21756
# 92      536686                                              22111
# 139     536687                                              21724
# 197     536688                                              21723
# 129     536689                                             85123A
# 147     536690                                              71053
# 339     536691                                              22632
# 226     536692                                              21914
# 101     536693                                              21731
# 5       536694                                              22960
# 20      536695                                              22139
# 19      536696                                              22112
# 167     536698                                              22634
# 296     536697                                              22634
# 391     536697                                              22634
# 328     536698                                              22111
# 150     536699                                              21724
# 59      536700                                              21723
# 60      536701                                             85123A
# 140     536702                                              71053
# 248     536703                                              22632
# 36      536704                                              21914
# 300     536705                                              21731
# 145     536706                                              22960
# 6       536707                                              22139
# 255     536708                                              22112
# 279     536709                                              22634
# 112     536710                                              22111
# 154     536711                                              21724
# 152     536712                                              21723
# 431     536713                                             85123A
# 24      536714                                              71053
# 343     536715                                              22632
# 333     536715                                              22632
# 212     536716                                              21914
# 364     536717                                              21731
# 196     536718                                              22960
# 402     536719                                              22139
# 278     536720                                              22112
# 43      536721                                              22634
# 137     536722                                              22111
# 387     536723                                              21724
# 291     536724                                              21723
# 398     536725                                             85123A
# 56      536726                                              71053
# 74      536727                                             84406B
# 429     536728                                             84029G
# 397     536729                                             84029E
# 169     536730                                              22752
# 52      536730                                              22752
# 306     536731                                              21730
# 335     536732                                              22633
# 365     536733                                              22632
# 96      536734                                              84879
# 334     536735                                              22745
# 242     536736                                              22748
# 172     536737                                              22749
# 65      536738                                              22310
# 244     536739                                              84969
# 349     536739                                              84969
# 252     536740                                              22623
# 50      536741                                              22622
# 407     536742                                              21754
# 178     536743                                              21755
# 292     536743                           LOVE BUILDING BLOCK WORD
# 275     536744                                              21777
#
#                                            Description Quantity  \
# 302                       SET 7 BABUSHKA NESTING BOXES        2
# 361                                WHITE METAL LANTERN        6
# 313                     CREAM CUPID HEARTS COAT HANGER        8
# 175                  GLASS STAR FROSTED T-LIGHT HOLDER        6
# 307                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 38                       RED WOOLLY HOTTIE WHITE HEART        6
# 47                 KNITTED UNION FLAG HOT WATER BOTTLE        6
# 211                          HAND WARMER RED POLKA DOT        6
# 31                              HAND WARMER UNION JACK        6
# 222                             IVORY KNITTED MUG COSY        6
# 360                                              84879       32
# 247                     BOX OF VINTAGE ALPHABET BLOCKS        2
# 230               DESCRIPTION HOME BUILDING BLOCK WORD        3
# 117                           POPPYS PLAYHOUSE KITCHEN        6
# 282                 BOX OF 6 ASSORTED COLOUR TEASPOONS        6
# 388                       BOX OF VINTAGE JIGSAW BLOCKS       -3
# 273                  FELTCRAFT PRINCESS CHARLOTTE DOLL        8
# 86                            POPPYS PLAYHOUSE BEDROOM        6
# 206                           LOVE BUILDING BLOCK WORD        3
# 438                        RECIPE BOX WITH METAL HEART        4
# 72                      SET 2 TEA TOWELS I LOVE LONDON        3
# 421                                DOORMAT NEW ENGLAND        6
# 267                 STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 430                               RED HARMONICA IN BOX       10
# 374                          SCANDINAVIAN REDS RIBBONS       10
# 341                                WHITE METAL LANTERN        6
# 383                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 10                           HAND WARMER RED POLKA DOT        6
# 30                               BLUE HARMONICA IN BOX       12
# 142                      RED TOADSTOOL LED NIGHT LIGHT       12
# 415       DESCRIPTION JAM MAKING SET WITH JARS DETAILS        6
# 17        DESCRIPTION JAM MAKING SET WITH JARS DETAILS        6
# 312                    RETROSPOT TEA SET CERAMIC 11 PC        6
# 11                          CHOCOLATE HOT WATER BOTTLE       10
# 319                                              22634        6
# 322                          SCANDINAVIAN REDS RIBBONS       10
# 338                         CHOCOLATE HOT WATER BOTTLE        6
# 79                        SET 7 BABUSHKA NESTING BOXES        2
# 68                   GLASS JAR DAISY FRESH COTTON WOOL        6
# 48                    SET OF 3 CAKE TINS PANTRY DESIGN        6
# 116  DESCRIPTION DESCRIPTION RED GLASS CANDLE HOLDE...        6
# 412                       RED GLASS CANDLE HOLDER STAR        6
# 284                            HANGING STAR WITH BELLS        6
# 417                  FELTCRAFT PRINCESS CHARLOTTE DOLL        8
# 309                                              21756        6
# 342                           POPPYS PLAYHOUSE BEDROOM        6
# 347                           POPPYS PLAYHOUSE KITCHEN        6
# 174                       SET 7 BABUSHKA NESTING BOXES        2
# 214                             HAND WARMER UNION JACK        6
# 133                          HAND WARMER RED POLKA DOT        6
# 183                          SCANDINAVIAN REDS RIBBONS       10
# 245                               RED HARMONICA IN BOX       10
# 99                  STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 437                       BOX OF VINTAGE JIGSAW BLOCKS        3
# 179                       BOX OF VINTAGE JIGSAW BLOCKS        3
# 91                      BOX OF VINTAGE ALPHABET BLOCKS        2
# 385                           COFFEE MUG APPLES DESIGN        6
# 63                            HOME BUILDING BLOCK WORD        3
# 336                           HOME BUILDING BLOCK WORD        3
# 403                           LOVE BUILDING BLOCK WORD        3
# 401                                              22386       10
# 350                            JUMBO BAG RED RETROSPOT       10
# 418  DESCRIPTION PACK OF 12 RED RETROSPOT TISSUES D...      200
# 121                   PACK OF 12 RED RETROSPOT TISSUES      200
# 15                   PACK OF 12 BLUE RETROSPOT TISSUES       20
# 386                   PACK OF 12 PINK POLKADOT TISSUES       20
# 423                    SET OF 7 BABUSHKA NESTING BOXES       10
# 186                              INVALIDDESCRIPTION123        5
# 106                              HEART OF WICKER LARGE        6
# 177                       PACK OF 6 SMALL FRUIT STRAWS       15
# 434                       PACK OF 6 SMALL FRUIT STRAWS       15
# 132                            JUMBO BAG PINK POLKADOT       10
# 320                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 249                    DESCRIPTION WHITE METAL LANTERN        6
# 332                     CREAM CUPID HEARTS COAT HANGER        8
# 75                 KNITTED UNION FLAG HOT WATER BOTTLE        6
# 314            RED WOOLLY HOTTIE WHITE HEART.: details        6
# 71                        SET 7 BABUSHKA NESTING BOXES        2
# 223                                              21730        6
# 379                             HAND WARMER UNION JACK        6
# 55                           HAND WARMER RED POLKA DOT        6
# 189          DESCRIPTION ASSORTED COLOUR BIRD ORNAMENT       32
# 107                           POPPYS PLAYHOUSE BEDROOM        6
# 366                           POPPYS PLAYHOUSE KITCHEN        6
# 321                  FELTCRAFT PRINCESS CHARLOTTE DOLL        8
# 156                             IVORY KNITTED MUG COSY        6
# 358                 BOX OF 6 ASSORTED COLOUR TEASPOONS        6
# 310                       BOX OF VINTAGE JIGSAW BLOCKS        3
# 428                     BOX OF VINTAGE ALPHABET BLOCKS        2
# 111                     BOX OF VINTAGE ALPHABET BLOCKS        2
# 123                           HOME BUILDING BLOCK WORD        3
# 239                              INVALIDDESCRIPTION123        3
# 77                         RECIPE BOX WITH METAL HEART        4
# 381                        RECIPE BOX WITH METAL HEART        4
# 327         DESCRIPTION SET 2 TEA TOWELS I LOVE LONDON        3
# 82                                 DOORMAT NEW ENGLAND        6
# 271                          SCANDINAVIAN REDS RIBBONS       10
# 298                              RED  HARMONICA IN BOX       10
# 40                  STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 199                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 13                                 WHITE METAL LANTERN        6
# 243                                              22632  unknown
# 32                                               21914       12
# 363                      RED TOADSTOOL LED NIGHT LIGHT       12
# 346                           JAM MAKING SET WITH JARS        6
# 416                    RETROSPOT TEA SET CERAMIC 11 PC       60
# 21                          CHOCOLATE HOT WATER BOTTLE       10
# 424                         CHOCOLATE HOT WATER BOTTLE       10
# 380                       BAKING SET 9 PIECE RETROSPOT        6
# 266                           JAM MAKING SET WITH JARS        6
# 1                                  DOORMAT NEW ENGLAND      100
# 301                         CHOCOLATE HOT WATER BOTTLE       10
# 39                        BAKING SET 9 PIECE RETROSPOT        6
# 308                          SCANDINAVIAN REDS RIBBONS       10
# 51                                RED HARMONICA IN BOX       10
# 213                 STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 134                      RED TOADSTOOL LED NIGHT LIGHT       12
# 369                           JAM MAKING SET WITH JARS        6
# 158                    RETROSPOT TEA SET CERAMIC 11 PC        6
# 102                         CHOCOLATE HOT WATER BOTTLE       10
# 64                        BAKING SET 9 PIECE RETROSPOT        6
# 263                  SCANDINAVIAN REDS RIBBONS DETAILS       10
# 141                               RED HARMONICA IN BOX       10
# 384                 STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 317                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 288                                WHITE METAL LANTERN        6
# 377                          HAND WARMER RED POLKA DOT        6
# 162                  DESCRIPTION BLUE HARMONICA IN BOX       12
# 114                      RED TOADSTOOL LED NIGHT LIGHT       12
# 200                           JAM MAKING SET WITH JARS        6
# 173        DESCRIPTION RETROSPOT TEA SET CERAMIC 11 PC        6
# 265                 CHOCOLATE HOT WATER BOTTLE DETAILS       10
# 221                       BAKING SET 9 PIECE RETROSPOT        6
# 228                       BAKING SET 9 PIECE RETROSPOT        6
# 3                DESCRIPTION SCANDINAVIAN REDS RIBBONS       10
# 392                               RED HARMONICA IN BOX       10
# 304                 STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 88                  STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 373                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 433                                WHITE METAL LANTERN        6
# 236                     CREAM CUPID HEARTS COAT HANGER        8
# 187                KNITTED UNION FLAG HOT WATER BOTTLE        6
# 426                      RED WOOLLY HOTTIE WHITE HEART        6
# 436                      RED WOOLLY HOTTIE WHITE HEART        6
# 241                       SET 7 BABUSHKA NESTING BOXES        2
# 375                  GLASS STAR FROSTED T-LIGHT HOLDER        6
# 166                 DESCRIPTION HAND WARMER UNION JACK        6
# 163                          HAND WARMER RED POLKA DOT        6
# 28                       ASSORTED COLOUR BIRD ORNAMENT       32
# 289                           POPPYS PLAYHOUSE BEDROOM        6
# 378                           POPPYS PLAYHOUSE KITCHEN        6
# 95                   FELTCRAFT PRINCESS CHARLOTTE DOLL        8
# 194                             IVORY KNITTED MUG COSY        6
# 46      DESCRIPTION BOX OF 6 ASSORTED COLOUR TEASPOONS        6
# 185                       BOX OF VINTAGE JIGSAW BLOCKS        3
# 42              BOX OF VINTAGE ALPHABET BLOCKS DETAILS        2
# 394                           HOME BUILDING BLOCK WORD        3
# 274                              INVALIDDESCRIPTION123        3
# 33                            LOVE BUILDING BLOCK WORD        3
# 160                        RECIPE BOX WITH METAL HEART        4
# 286                        RECIPE BOX WITH METAL HEART        4
# 229                           JAM MAKING SET WITH JARS        6
# 120                           JAM MAKING SET WITH JARS        6
# 181                                DOORMAT NEW ENGLAND       10
# 269                         CHOCOLATE HOT WATER BOTTLE       10
# 287                       BAKING SET 9 PIECE RETROSPOT  unknown
# 210                          SCANDINAVIAN REDS RIBBONS      100
# 367                               RED HARMONICA IN BOX       10
# 406                 STRIPED CHARLIE+LOLA CHARLOTTE BAG       20
# 192                 WHITE HANGING HEART T-LIGHT HOLDER        6
# 255      Australia        PROMO10  Bank Transfer
# 279      Australia        PROMO10    Credit Card
# 112  South America        PROMO20      Gift Card
# 154  North America      DISCOUNT5      Gift Card
# 152         Europe        PROMO10           Cash
# 431           Asia            NaN    Credit Card
# 24            Asia      DISCOUNT5      Gift Card
# 343  North America        PROMO10           Cash
# 333  South America        PROMO20    Credit Card
# 212         Europe            NaN         PayPal
# 364         Europe      DISCOUNT5           Cash
# 196  North America      DISCOUNT5    Credit Card
# 402  North America         SALE15         PayPal
# 278           Asia            NaN  Bank Transfer
# 43       Australia      DISCOUNT5      Gift Card
# 137         Europe            NaN         PayPal
# 387      Australia            NaN    Credit Card
# 291  South America        PROMO10      Gift Card
# 398         Europe        PROMO20           Cash
# 56       Australia        PROMO10      Gift Card
# 74   North America         SALE15      Gift Card
# 429           Asia         SALE15  Bank Transfer
# 397  North America      DISCOUNT5         PayPal
# 169  North America      DISCOUNT5  Bank Transfer
# 52   South America      DISCOUNT5           Cash
# 306         Europe            NaN         PayPal
# 335           Asia      DISCOUNT5      Gift Card
# 365           Asia        PROMO20  Bank Transfer
# 96       Australia            NaN  Bank Transfer
# 334         Europe            NaN         PayPal
# 242      Australia            NaN           Cash
# 172         Europe      DISCOUNT5      Gift Card
# 65       Australia         SALE15  Bank Transfer
# 244  South America         SALE15    Credit Card
# 349         Europe      DISCOUNT5           Cash
# 252  South America        PROMO20           Cash
# 50            Asia            NaN           Cash
# 407         Europe         SALE15           Cash
# 178           Asia      DISCOUNT5  Bank Transfer
# 292      Australia        PROMO10           Cash
# 275         Europe         SALE15      Gift Card
#
# [441 rows x 24 columns]

# %%
# Verificación de datos y se observan en orden 
retail2_df = retail2_df.sort_values(by='InvoiceDate') 
print(retail2_df['StockCode'].unique())
# Out:
# ['22752' '71053' '84406B' '21730' '85123A' '84029E' '84029G' '22632'
#  '22633' '21755' '22745' '22749' '22623' '84969' '21754' '22622' '84879'
#  '22310' '22748' '21777' '84988' '21756' '21724' '21723' '22111' '21914'
#  '21731' '22960' '22139' '22112' '22634' 'SCANDINAVIAN REDS RIBBONS'
#  '22725' '22624' '22570' '22571' '22754' '22386' '85099B' '84907B'
#  '84907C' '84907A' '22751' '22382' '22469' '22384'
#  '{"description": ["RED WOOLLY HOTTIE WHITE HEART.: details"]}'
#  'RED  HARMONICA IN BOX' 'STRIPED CHARLIE+LOLA CHARLOTTE BAG'
#  'JAM MAKING SET WITH JARS' 'SET 2 TEA TOWELS I LOVE LONDON' nan
#  'HAND WARMER RED POLKA DOT' 'BOX OF 6 ASSORTED COLOUR TEASPOONS'
#  'RED HARMONICA IN BOX' 'LOVE BUILDING BLOCK WORD']

# %%
# Eliminar letras al final de los códigos de stock
#retail2_df['StockCode'] = retail2_df['StockCode'].str.replace(r'([0-9]+)[A-Za-z]$', r'\1', regex=True)

# Mostrar los valores únicos después de la limpieza
#print(retail2_df['StockCode'].unique())

# %%
# Identificar las filas de la columna StockCode contiene descripciones en lugar de códigos 
mask = retail2_df['StockCode'].str.contains(r'[a-zA-Z]', na=False)
# Mover los datos de 'StockCode' a 'Description' donde sea necesario
retail2_df.loc[mask, 'Description'] = retail2_df.loc[mask, 'StockCode']
retail2_df.loc[mask, 'StockCode'] = np.nan
print(retail2_df['StockCode'].unique())
# Out:
# ['22752' '71053' nan '21730' '22632' '22633' '21755' '22745' '22749'
#  '22623' '84969' '21754' '22622' '84879' '22310' '22748' '21777' '84988'
#  '21756' '21724' '21723' '22111' '21914' '21731' '22960' '22139' '22112'
#  '22634' '22725' '22624' '22570' '22571' '22754' '22386' '22751' '22382'
#  '22469' '22384']

# %%
# Contar los valores nulos en la columna 'StockCode'
nulos_stockcode = retail2_df['StockCode'].isnull().sum()

print(f"Cantidad de datos vacíos en la columna 'StockCode': {nulos_stockcode}")
# Out:
# Cantidad de datos vacíos en la columna 'StockCode': 64

# %%
# Crear un diccionario con las descripciones y sus correspondientes códigos de stock
description_to_stockcode = retail2_df.dropna(subset=['StockCode']).drop_duplicates(subset=['Description']).set_index('Description')['StockCode'].to_dict()

# Rellenar los valores faltantes en 'StockCode'
retail2_df['StockCode'] = retail2_df.apply(lambda row: description_to_stockcode.get(row['Description'], row['StockCode']), axis=1)

# %% [markdown]
# Explicación del Código: Crear un diccionario de descripciones a códigos de stock: dropna(subset=['StockCode']): Elimina las filas donde ‘StockCode’ es NaN. drop_duplicates(subset=['Description']): Elimina duplicados basados en la columna ‘Description’. set_index('Description')['StockCode'].to_dict(): Crea un diccionario donde las claves son las descripciones y los valores son los códigos de stock. Rellenar los valores faltantes en ‘StockCode’ usando el diccionario: apply(lambda row: description_to_stockcode.get(row['Description'], row['StockCode']), axis=1): Aplica una función lambda a cada fila del DataFrame. La función usa el diccionario para rellenar los valores faltantes en ‘StockCode’ basados en la ‘Description’.

# %%
# Contar los valores nulos en la columna 'StockCode'
nulos_stockcode = retail2_df['StockCode'].isnull().sum()

print(f"Cantidad de datos vacíos en la columna 'StockCode': {nulos_stockcode}")
# Out:
# Cantidad de datos vacíos en la columna 'StockCode': 56

# %%
# Seleccionar solo las columnas 'StockCode' y 'Description'
filtered_df = retail2_df[['StockCode', 'Description']]

# Mostrar las filas con valores vacíos en 'StockCode'
missing_values = filtered_df[filtered_df['StockCode'].isnull()]

# Mostrar las filas filtradas
print(missing_values)
# Out:
#     StockCode                                        Description
# 313       NaN                                             84406B
# 307       NaN                                             85123A
# 38        NaN                                             84029E
# 47        NaN                                             84029G
# 383       NaN                                             85123A
# 350       NaN                                             85099B
# 418       NaN                                             84907B
# 121       NaN                                             84907B
# 15        NaN                                             84907C
# 386       NaN                                             84907A
# 320       NaN                                             85123A
# 332       NaN                                             84406B
# 75        NaN                                             84029G
# 314       NaN  {"description": ["RED WOOLLY HOTTIE WHITE HEAR...
# 298       NaN                              RED  HARMONICA IN BOX
# 199       NaN                                             85123A
# 371       NaN                                             85123A
# 261       NaN                                             85123A
# 410       NaN                                             84406B
# 14        NaN                                             84029G
# 125       NaN                                             84029E
# 259       NaN                                             85123A
# 235       NaN                                             85123A
# 317       NaN                                             85123A
# 373       NaN                                             85123A
# 236       NaN                                             84406B
# 187       NaN                                             84029G
# 426       NaN                                             84029E
# 436       NaN                                             84029E
# 192       NaN                                             85123A
# 324       NaN                                             85123A
# 69        NaN                                             85123A
# 104       NaN                                             85123A
# 198       NaN                                             84406B
# 66        NaN                                             84029G
# 303       NaN                                             84029E
# 62        NaN                                             85123A
# 81        NaN                                             85123A
# 440       NaN                                                NaN
# 233       NaN                                             85123A
# 208       NaN                                             85123A
# 207       NaN                                             84406B
# 23        NaN                                             84029G
# 262       NaN                                             84029E
# 396       NaN                                             85123A
# 110       NaN                                             85123A
# 209       NaN                                             84406B
# 67        NaN                                             84029G
# 202       NaN                                             84029E
# 129       NaN                                             85123A
# 60        NaN                                             85123A
# 431       NaN                                             85123A
# 398       NaN                                             85123A
# 74        NaN                                             84406B
# 429       NaN                                             84029G
# 397       NaN                                             84029E

# %%
# Crear un diccionario con las descripciones y sus correspondientes códigos de stock
description_to_stockcode = {
    'RED WOOLLY HOTTIE WHITE HEART': 84029
}
# Rellenar los valores faltantes en 'StockCode'
retail2_df['StockCode'] = retail2_df.apply(lambda row: description_to_stockcode.get(row['Description'], row['StockCode']), axis=1)

# %%
# Contar los valores nulos en la columna 'StockCode'
nulos_stockcode = retail2_df['StockCode'].isnull().sum()

print(f"Cantidad de datos vacíos en la columna 'StockCode': {nulos_stockcode}")
# Out:
# Cantidad de datos vacíos en la columna 'StockCode': 56

# %% [markdown]
# # Limpieza de datos :Columna Quantity
# - Imprimir valores únicos
# - cambiar la columna de datos objet a int
# - Donde sale unknown colocar 6 ya que la description correspondiente GLASS STAR FROSTED T-LIGHT HOLDER las otras tiene totas el mismo valor

# %%
# Imprimir valores únicos
retail2_df=retail2_df.sort_values(by='Quantity')
print(retail2_df['Quantity'].unique())
# Out:
# ['-20' '-3' '-6' '-60' '10' '100' '12' '15' '2' '20' '200' '3' '32' '4'
#  '5' '6' '60' '8' 'unknown' nan]

# %%
# Reemplazar 'unknown' con un valor numérico, por ejemplo, 6
retail2_df['Quantity'] = retail2_df['Quantity'].replace('unknown', 6)
reatil2_df = retail2_df.sort_values(by='Quantity')
print(retail2_df['Quantity'].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[190], line 3
#       1 # Reemplazar 'unknown' con un valor numérico, por ejemplo, 6
#       2 retail2_df['Quantity'] = retail2_df['Quantity'].replace('unknown', 6)
# ----> 3 reatil2_df = retail2_df.sort_values(by='Quantity')
#       4 print(retail2_df['Quantity'].unique())
#
# File c:\Users\nanaw\anaconda3\envs\Curso_Python\Lib\site-packages\pandas\core\frame.py:7200, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7197     if isinstance(ascending, (tuple, list)):
#    7198         ascending = ascending[0]
# -> 7200     indexer = nargsort(
#    7201         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    7202     )
#    7203 else:
#    7204     if inplace:
#
# File c:\Users\nanaw\anaconda3\envs\Curso_Python\Lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
#     441     indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'int' and 'str'
